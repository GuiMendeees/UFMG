# %% [markdown]
# Nome: Guilherme Mendes de Oliveira
# 1)
# A)
#
# P					A
# 	1	0	0			3	2	4
# 	0	1	0			1	1	2
# 	0	0	1			4	3	-2
#
# Permutando as Linhas de P A
#
#
# P					A
# 	0	0	1			4	3	-2
# 	1	0	0			3	2	4
# 	0	1	0			1	1	2
#
#
# Pivô = 4
# m21 = 3/4
# m31 = 1/4
#
#
# Pivô 1/4
# m32 = (1/4)/(1/4) = 1
#
# L					U
# 	1	0	0			4	3	-2
# 	3/4	1	0			0	1/4	-22/4
# 	1/4	1	1			0	0	8
#
#
# B)
# det(A) = det(L)* det(U) * (-1)^permutações
# det(A) = 1*(4*1/4*8)* (-1)^3
# det(A) = -8
#
# 2)
#
# A			*      x   = b
#
# 	9	18	       x     3
# 	18	52	       y     4
#
#
# L*L^T	A	0		A	B
# 		B	C		0	C
#
#
# A²	A*B	        =     9  18
# A*B	B²*C²	          18 52
#
# A² = 9
# A = 3
#
# A*B = 18
# B = 6
# B²*C² = 52
# C = 4
#
#
# L				L.t
#
# 	3	0			3	6
# 	6	4			0	4
#
#
#
# L        *         y         =   b
#
# 	3	0	       y1            3
# 	6	4	       y2            4
#
#     y1 = 1
#     y2 = -1/2
#
#
# L.t       *       x            =      y
#
# 	3	6	      x1                  1
# 	0	4	      x2                 -1/2
#
# 	x2 = -1/8
#     x1 = 7/12
#
# 3)
# r=	b	-	A*			x0
# 	3		9	18		0,5
# 	4		18	52		-0,1
#
# r=
#     0,3
#     0,2
#
# B)
# A*			c	=	r
# 9	18		c0		0,3
# 18	52		c1		0,2
#
#
# c=
#     -1/90
#      1/45
#
# 4)
# F - As entradas de A devem ser positivas
# V - O escalonamento pode resultar em linhas nulas, podendo o sistema ser inconscistente ou ter infinitas soluções
# F - Cholesky executa operações aproveitando a simetria, essa simultaneadade demanda mais alocação de memória
